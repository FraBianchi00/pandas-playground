# %% [markdown]
# # 03 - Aggrega e raggruppa

# %% [markdown]
# ## Sezione 1: Warm up

# %%
import pandas as pd

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic["Sex"].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
titanic["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## Sezione 2: Groupby

# %%
titanic.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
titanic.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
titanic.groupby(["Pclass", "Sex"])["Survived"].mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
titanic.groupby("Pclass")["Age"].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# ## Sezione 3: .agg()

# %%
titanic.groupby("Pclass")["Age"].agg(["mean", "median", "std"])
# Out:
#              mean  median        std
# Pclass
# 1       38.233441    37.0  14.802856
# 2       29.877630    29.0  14.001077
# 3       25.140620    24.0  12.495398

# %%
titanic.groupby(["Pclass", "Sex"]).agg(
    eta_media=("Age", "mean"), 
    fare_medio=("Fare", "mean"), 
    sopravvissuti=("Survived", "sum"),
    totale=("Survived", "size"))
# Out:
#                eta_media  fare_medio  sopravvissuti  totale
# Pclass Sex
# 1      female  34.611765  106.125798             91      94
#        male    41.281386   67.226127             45     122
# 2      female  28.722973   21.970121             70      76
#        male    30.740707   19.741782             17     108
# 3      female  21.750000   16.118810             72     144
#        male    26.507589   12.661633             47     347

# %%
titanic.groupby(["Pclass", "Sex"])["Age"].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %% [markdown]
# ## Sezione 4: Esercizi di ripasso

# %%
titanic.groupby("Sex")[["Age", "Fare"]].mean()
# Out:
#               Age       Fare
# Sex
# female  27.915709  44.479818
# male    30.726645  25.523893

# %%
titanic.groupby(["Pclass", "Embarked"]).size()
# Out:
# Pclass  Embarked
# 1       C            85
#         Q             2
#         S           127
# 2       C            17
#         Q             3
#         S           164
# 3       C            66
#         Q            72
#         S           353
# dtype: int64

# %%
titanic.groupby("Sex").agg(eta_media=("Age", "mean"))
# Out:
#         eta_media
# Sex
# female  27.915709
# male    30.726645
